# %%
#String
#you need the name of the variable uncapitalized to not make it a constant. Strings are text encased in 'xxxxx' spaces are considered
#string characters.
welcomeMessage='Welcome to CIS 115'
#make sure to make variables descriptive to avoid 3rd parties being unable to decipher the code. Camelcase them too.

#integers
studentsInClassroom=32
booksInLibrary=10000
smallValue=-11111111100
#Integer variables can't be switched between string variables
#Integers can be made any number including negatives
#Can't be decimal point numbers due to not being float variables

# %%
#A+B=C
#C=A+B
variableA=int(input('Give Variable A: '))
variableB=int(input('Give Variable B: '))
variableC=variableA+variableB
print(variableC)
# Out:
# Give Variable A: -4
# Give Variable B: 5
# 1

# %%
nameOfStudent=str(input('What is your name?: '))
homeworkForToday=', you have to code A+B=C'
print(nameOfStudent+homeworkForToday)
# Out:
# What is your name?: Logan
# Logan, you have to code A+B=C

# %%
#and
#or
#!=
print(True or True)
print(True or False)
print(False or True)
print(False or True)
print(True or True or False)
print(False or False)
# Out:
# True
# True
# True
# True
# True
# False

# %%
print( not False)
print( not True)
print( not True and True)
# Out:
# True
# False
# False

# %%
goToClass=True
haveATest=True
studyForTest=True
print('It is',(goToClass or studyForTest) and haveATest, 'that you will pass the test')
# Out:
# It is True that you will pass the test

# %%
goToClass=True
haveATest=True
studyForTest=True
if((goToClass or studyForTest) and haveATest):
  print('Great Job!!')
# Out:
# Great Job!!

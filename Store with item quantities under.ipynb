# %%
shoppingCart=['What would you like?: ','What would you like?: ','What would you like?: ','What would you like?: ']
itemAnswers=[]
itemAmounts=['How many would you like?: ','How many would you like?: ','How many would you like?: ','How many would you like?: ']
itemMultipliers=[]
for question in shoppingCart:
  print(question)
  itemAnswer=input()
  itemAnswers.append(itemAnswer)
for query in itemAmounts:
  print(query)
  itemMultiplier=input()
  itemMultipliers.append(itemMultiplier)
print(itemAnswers)
print(itemMultipliers)
# Out:
# What would you like?:
# Bruh
# What would you like?:
# Do
# What would you like?:
# You
# What would you like?:
# Care
# How many would you like?:
# 3
# How many would you like?:
# 2
# How many would you like?:
# 3
# How many would you like?:
# 1
# ['Bruh', 'Do', 'You', 'Care']
# ['3', '2', '3', '1']
